# %% [markdown]
# # 1. Tokenization & Vocabulary
#
# **Goal:** Split real text into subword tokens and build a small vocabulary from it — the first, unglamorous step every transformer starts from.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) build-your-own-transformer notebook series. These notebooks are organized in the order you'd actually *build* a transformer, not the order the tutorial lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# [Embeddings & Positional Encoding →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/02-embeddings-positional-encoding.ipynb)
