# %% [markdown]
# # 2. Embeddings & Positional Encoding
#
# **Goal:** Turn token IDs into learned vectors, and add positional information so order isn't lost — on a real (if small) piece of text, not a 3-token toy example.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) build-your-own-transformer notebook series. These notebooks are organized in the order you'd actually *build* a transformer, not the order the tutorial lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# [← Tokenization & Vocabulary](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/01-tokenization-vocabulary.ipynb) &nbsp;|&nbsp; [Self-Attention From Scratch →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/03-self-attention-from-scratch.ipynb)
