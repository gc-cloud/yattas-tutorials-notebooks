# %% [markdown]
# # 8. Training Loop
#
# **Goal:** Train a small character-level model on a tiny corpus — sized to finish in a few minutes on Colab's free CPU runtime. No GPU required.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) series' build-your-own-transformer notebooks — companion to [Lesson 17](https://yattas.com/tutorials/transformers/17-build-your-own-transformer/). These notebooks are organized in the order you'd actually *build* a transformer, which isn't the same order the lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# ---
#
# *Content coming soon.*
#
# [← Stacking Blocks & the Output Head](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/07-stacking-blocks-output-head.ipynb) &nbsp;|&nbsp; [Generation & Sampling →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/09-generation-sampling.ipynb)
