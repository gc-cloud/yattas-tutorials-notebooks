# %% [markdown]
# # 4. Multi-Head Attention
#
# **Goal:** Run several attention heads in parallel and recombine them with a learned output projection.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) build-your-own-transformer notebook series. These notebooks are organized in the order you'd actually *build* a transformer, not the order the tutorial lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# [← Self-Attention From Scratch](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/03-self-attention-from-scratch.ipynb) &nbsp;|&nbsp; [Feedforward, Residuals & LayerNorm →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/05-feedforward-residuals-layernorm.ipynb)
