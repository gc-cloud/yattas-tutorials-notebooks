# %% [markdown]
# # 3. Self-Attention From Scratch
#
# **Goal:** Implement scaled dot-product attention over a real sentence, with more tokens and dimensions than the toy walkthrough on the lesson page.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) build-your-own-transformer notebook series. These notebooks are organized in the order you'd actually *build* a transformer, not the order the tutorial lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# [← Embeddings & Positional Encoding](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/02-embeddings-positional-encoding.ipynb) &nbsp;|&nbsp; [Multi-Head Attention →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/04-multi-head-attention.ipynb)
