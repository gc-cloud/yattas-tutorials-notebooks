# %% [markdown]
# # 5. Feedforward, Residuals & LayerNorm
#
# **Goal:** Build the position-wise feedforward network and wrap it — and attention — in residual connections and layer normalization.
#
# Part of the [Understanding Transformers](https://yattas.com/tutorials/transformers/) series' build-your-own-transformer notebooks — companion to [Lesson 17](https://yattas.com/tutorials/transformers/17-build-your-own-transformer/). These notebooks are organized in the order you'd actually *build* a transformer, which isn't the same order the lessons *teach* the concepts in.
#
# Runs entirely on Colab's free CPU tier — nothing here needs a GPU.
#
# ---
#
# *Content coming soon.*
#
# [← Multi-Head Attention](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/04-multi-head-attention.ipynb) &nbsp;|&nbsp; [Assembling One Transformer Block →](https://colab.research.google.com/github/gc-cloud/yattas-tutorials-notebooks/blob/main/06-assembling-a-transformer-block.ipynb)
